# %%
import numpy as np
import pandas as pd
import json
import requests
import time
import os
import shutil
import matplotlib.pyplot as plt

# %%
from cryptodata import *
pd.set_option('display.max_rows',10)

# %% [markdown]
# - Primeiro, nós criamos alguns pares(isso demora um pouco da primeira vez para baixar os dados da internet):

# %%
btc = Pair('btcusdt', period=24*60*60)
eth = Pair('ethusd')
ltc = Pair('ltcusd')
# Out:
# btcusdt
# ethusd
# ltcusd

# %% [markdown]
# - Em seguida calculamos o índice para cada um dos pares

# %%
index_btc = pair_index(btc)
index_eth = pair_index(eth)
index_ltc = pair_index(ltc)

# %% [markdown]
# - E depois plotamos, para uma melhor visualização

# %%
plot_df(index_btc)
plot_df(index_eth)
plot_df(index_ltc)
